# %%
l = [ 12,3,3,4,43]
l1 = []
for i in l :
    l1.append(i**2)

# %%
l1
# Out:
# [144, 9, 9, 16, 1849]

# %%
l
# Out:
# [12, 3, 3, 4, 43]

# %%
[i**2 for i in l]
# Out:
# [144, 9, 9, 16, 1849]

# %%
[i+2 for i in l]
# Out:
# [14, 5, 5, 6, 45]

# %%
[i/2 for i in l]
# Out:
# [6.0, 1.5, 1.5, 2.0, 21.5]

# %%
[i for i in l if i% 2 ==0]
# Out:
# [12, 4]

# %%
k= ['kingkumar' , 'pillumangu', ' hujai', 'rakesh']

# %%
k
# Out:
# ['kingkumar', 'pillumangu', ' hujai', 'rakesh']

# %%
[ i.upper() for i in k  ]
# Out:
# ['KINGKUMAR', 'PILLUMANGU', ' HUJAI', 'RAKESH']

# %%
l
# Out:
# [12, 3, 3, 4, 43]

# %%
(i**2 for i in l)
# Out:
# <generator object <genexpr> at 0x7f6cd47414d0>

# %%
list(i**2 for i in l)
# Out:
# [144, 9, 9, 16, 1849]

# %%
m = {' key1' : 1, 'key2' : 2 , 'key3' : 3}

# %%
{k:v**2 for k , v in m.items()}
# Out:
# {' key1': 1, 'key2': 4, 'key3': 9}

# %%
m
# Out:
# {' key1': 1, 'key2': 2, 'key3': 3}

# %%
{k : v for k , v in m.items() if v > 1}
# Out:
# {'key2': 2, 'key3': 3}

# %%
#function part 1

# %%
def test():
    pass

# %%
def test1():
    print('maskar')

# %%
test1()
# Out:
# maskar
